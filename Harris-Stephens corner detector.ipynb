# %% [markdown]
# # Load dependencies

# %%
# %cd CVPR
from ComputerVision.harrisStephensCornerDetector import HarrisStephens
from ComputerVision.cannyEdgeDetection import CannyEdge
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %cd ..
# Out:
# /Users/ipmach/Documents/cvpr/CVPR
# /Users/ipmach/Documents/cvpr

# %% [markdown]
# # Load image

# %%
img = cv2.imread("img/building.tif", cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %% [markdown]
# # Apply Harris-Stephens corner detector
#
# This algorithm is not full complete, only work pixel-wise

# %%
img2 = HarrisStephens.apply(img, kernel_size=3, k=0.249, t=0.01)
# Out:
# Harris-Stephens corner detector
#     (1/5) Differentiation
# ...
#     (2-3/5) Pre-compute / Integration
# ...
#     (4/5) Compute R
# ...
#     (5/5) Apply threshold and non maxima supression
# ...
# Complete!

# %%
plt.imshow(img, cmap='gray')
plt.scatter(np.nonzero(img2)[1], np.nonzero(img2)[0])

# %%
np.unique(img2, return_counts=True)
# Out:
# (array([0, 1]), array([359137,    863]))
