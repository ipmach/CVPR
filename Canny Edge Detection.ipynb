# %% [markdown]
# # Load dependencies

# %%
# %cd CVPR
from ComputerVision.cannyEdgeDetection import CannyEdge
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %cd ..
# Out:
# /Users/ipmach/Documents/cvpr/CVPR
# /Users/ipmach/Documents/cvpr

# %% [markdown]
# # Load image

# %%
img = cv2.imread("img/engine.pgm", cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %% [markdown]
# # Canny Edge Detection method

# %% [markdown]
# ## With incremental grow
# Better result, much slower

# %%
img2 = CannyEdge.apply(img)

plt.imshow(img2, cmap='gray')
# Out:
# Applying Canny edge detector
#     (1/5) Integration
# ...
#     (2/5) Differentiation
# ...
#     (3/5) Non-maxima suppression
# ...
#     (4/5) Hysteresis (or Dual) thresholding
#     (5/5) Connectivity analysis
# Complete!

# %% [markdown]
# ## Without incremental grow
# less clean, much faster

# %%
img2 = CannyEdge.apply(img, do_grow=False)

plt.imshow(img2, cmap='gray')
# Out:
# Applying Canny edge detector
#     (1/5) Integration
# ...
#     (2/5) Differentiation
# ...
#     (3/5) Non-maxima suppression
# ...
#     (4/5) Hysteresis (or Dual) thresholding
#     (5/5) Connectivity analysis
# Complete!
